# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame({"col1":[1,2,3], "col2":[2,3,4]})

# %%
df.min()
# Out:
# col1    1
# col2    2
# dtype: int64

# %%
df.corr()
# Out:
#       col1  col2
# col1   1.0   1.0
# col2   1.0   1.0

# %%
df.to_numpy()
# Out:
# array([[1, 2],
#        [2, 3],
#        [3, 4]])

# %%
def yeet(arr1, arr2):
    return 2

# %%
def get_correl_matrix(arr : np.ndarray, method ,column_name_list: list = None, is_symetric: bool = False) -> pd.DataFrame:
    shape = arr.shape
    cols = shape[1]
    result = np.ones(shape=(cols,cols))

    if is_symetric:
        return pd.DataFrame(arr).corr(method=method)

    if method == "transfer_entropy":
        method = get_transfer_entropy

    for i in range(shape[1]):
        for j in range(shape[1]):
            if i == j:
                continue
            arr1 = arr[:,j]
            arr2 = arr[:,i]
            result[i,j] = method(arr[i], arr[j])
    
    if column_name_list is not None:
        result = pd.DataFrame(data=result, columns=column_name_list, index=column_name_list)
        
    return result

# %%
get_correl_matrix(df.to_numpy(), "dfj", column_name_list=["col1", "col2"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-2e5976bf48ca> in <module>
# ----> 1 get_correl_matrix(df.to_numpy(), "dfj", column_name_list=["col1", "col2"])
#
# <ipython-input-9-5d55a245168f> in get_correl_matrix(arr, method, column_name_list, is_symetric)
#      16             arr1 = arr[:,j]
#      17             arr2 = arr[:,i]
# ---> 18             result[i,j] = method(arr[i], arr[j])
#      19
#      20     if column_name_list is not None:
#
# TypeError: 'str' object is not callable
